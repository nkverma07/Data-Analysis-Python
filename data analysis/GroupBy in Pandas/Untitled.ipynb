# %%
import pandas as pd

import numpy as np

from sklearn.impute import SimpleImputer

df = pd.read_csv("googleplaystore.csv")

# %%
impute = SimpleImputer(missing_values = np.nan , strategy = 'mean') 
impute.fit(df.iloc[ : , 2:3 ].values) 
df.iloc[ : , 2:3 ] = impute.transform(df.iloc[ : , 2:3 ].values) 
df = df.dropna()

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_pr = df[df['Category']=='ART_AND_DESIGN']

# %%
df_pr[df_pr['Rating']>4.5]
# Out:
#                                                     App        Category  \
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 9                         Kids Paint Free - Drawing Fun  ART_AND_DESIGN
# 13                                Mandala Coloring Book  ART_AND_DESIGN
# 16         Photo Designer - Write your name with shapes  ART_AND_DESIGN
# 19                                         ibis Paint X  ART_AND_DESIGN
# 22              Superheroes Wallpapers | 4K Backgrounds  ART_AND_DESIGN
# 24                          HD Mickey Minnie Wallpapers  ART_AND_DESIGN
# 25                           Harley Quinn wallpapers HD  ART_AND_DESIGN
# 26                        Colorfit - Drawing & Coloring  ART_AND_DESIGN
# 34                                      I Creative Idea  ART_AND_DESIGN
# 36       UNICORN - Color By Number & Pixel Art Coloring  ART_AND_DESIGN
# 38                       PIP Camera - PIP Collage Maker  ART_AND_DESIGN
# ...

# %%
df_pr.sort_values(by = 'Rating', ascending = True).head(10)
# Out:
#                                                     App        Category  \
# 5179                              Ai illustrator viewer  ART_AND_DESIGN
# 35                     How to draw Ladybug and Cat Noir  ART_AND_DESIGN
# 43                                        Paint Splash!  ART_AND_DESIGN
# 6               Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN
# 1                                   Coloring book moana  ART_AND_DESIGN
# 28                                Pencil Sketch Drawing  ART_AND_DESIGN
# 20                          Logo Maker - Small Business  ART_AND_DESIGN
# 5258  AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper  ART_AND_DESIGN
# 39        How To Color Disney Princess - Coloring Pages  ART_AND_DESIGN
# 0        Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
#
#       Rating Reviews  Size  Installs  Type Price Content Rating  \
# 5179     3.4     486  5.9M  100,000+  Free     0       Everyone
# ...

# %%
df["Category"].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
df_pr = df[df["Type"] == "Free" ]

# %%
df_pr
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_pr.groupby("Category").count()["Type"].sort_values(ascending = True)
# Out:
# Category
# BEAUTY                   53
# PARENTING                58
# COMICS                   60
# ART_AND_DESIGN           61
# EVENTS                   63
# WEATHER                  74
# AUTO_AND_VEHICLES        82
# LIBRARIES_AND_DEMO       83
# HOUSE_AND_HOME           88
# FOOD_AND_DRINK          125
# MAPS_AND_NAVIGATION     132
# ENTERTAINMENT           147
# EDUCATION               152
# VIDEO_PLAYERS           171
# BOOKS_AND_REFERENCE     202
# DATING                  227
# TRAVEL_AND_LOCAL        246
# SHOPPING                258
# NEWS_AND_MAGAZINES      281
# SOCIAL                  292
# PERSONALIZATION         308
# PHOTOGRAPHY             313
# HEALTH_AND_FITNESS      325
# FINANCE                 349
# MEDICAL                 354
# SPORTS                  360
# COMMUNICATION           360
# LIFESTYLE               363
# PRODUCTIVITY            396
# BUSINESS                446
# TOOLS                   764
# GAME                   1061
# ...

# %%
df_pr = df[df["Rating"] >=4.0 ]
df_pr.groupby("Category").count()["Rating"].sort_values(ascending = False)
# Out:
# Category
# FAMILY                 1339
# GAME                    948
# TOOLS                   505
# PRODUCTIVITY            291
# PERSONALIZATION         282
# COMMUNICATION           268
# MEDICAL                 266
# SPORTS                  265
# PHOTOGRAPHY             264
# HEALTH_AND_FITNESS      251
# FINANCE                 246
# SOCIAL                  224
# BUSINESS                223
# LIFESTYLE               213
# SHOPPING                207
# NEWS_AND_MAGAZINES      173
# TRAVEL_AND_LOCAL        165
# BOOKS_AND_REFERENCE     149
# EDUCATION               149
# DATING                  126
# ENTERTAINMENT           108
# VIDEO_PLAYERS           105
# MAPS_AND_NAVIGATION      84
# FOOD_AND_DRINK           82
# HOUSE_AND_HOME           59
# WEATHER                  59
# ART_AND_DESIGN           55
# AUTO_AND_VEHICLES        55
# LIBRARIES_AND_DEMO       49
# EVENTS                   42
# PARENTING                41
# COMICS                   40
# ...

# %%
df.groupby('Category')['Rating'].agg(['mean', 'median', 'min', 'max', 'count', 'std', 'var'])
# Out:
#                          mean    median  min  max  count       std       var
# Category
# ART_AND_DESIGN       4.371804  4.400000  3.4  5.0     61  0.328878  0.108160
# AUTO_AND_VEHICLES    4.154934  4.193338  2.1  4.9     75  0.517768  0.268084
# BEAUTY               4.270923  4.200000  3.1  4.9     47  0.330482  0.109218
# BOOKS_AND_REFERENCE  4.286498  4.200000  2.7  5.0    196  0.396044  0.156851
# BUSINESS             4.148185  4.193338  1.0  5.0    400  0.520514  0.270935
# COMICS               4.133072  4.300000  2.8  5.0     51  0.563057  0.317033
# COMMUNICATION        4.121284  4.193338  1.0  5.0    265  0.449033  0.201630
# DATING               4.001133  4.193338  1.0  5.0    212  0.608345  0.370083
# EDUCATION            4.385526  4.400000  3.5  4.9    111  0.260060  0.067631
# ENTERTAINMENT        4.146667  4.200000  3.0  4.7     90  0.284901  0.081169
# EVENTS               4.383744  4.300000  3.7  5.0     57  0.316126  0.099936
# ...

# %%
df.groupby('Category').mean()['Rating'].sort_values(ascending = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     876 for i, group in enumerate(splitter):
# --> 877     res = func(group)
#     878     res = extract_result(res)
#
# ...

# %%
df[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 df[1]
#
# ...
