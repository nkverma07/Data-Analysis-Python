# %%
import pandas as pd

# %%
import numpy as np

# %%
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv("googleplaystore.csv")

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['Category'] == 'FAMILY'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836     True
# 10837     True
# 10838    False
# 10839    False
# 10840    False
# Name: Category, Length: 10841, dtype: bool

# %%
df['Category'] == 'ART_AND_DESIGN'
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840    False
# Name: Category, Length: 10841, dtype: bool

# %%
df[df['Category'] == 'ART_AND_DESIGN']
# Out:
#                                                     App        Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                   Coloring book moana  ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint  ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                 ...             ...
# 7174                            Easy DIY CD Craft Ideas  ART_AND_DESIGN
# 8679                                       Dp for girls  ART_AND_DESIGN
# 8712             Name Art DP - Focus n Filter Text 2018  ART_AND_DESIGN
# 8871                             Test Application DT 02  ART_AND_DESIGN
# 8888            Spring flowers theme couleurs d t space  ART_AND_DESIGN
#
#       Rating Reviews  Size     Installs  Type Price Content Rating  \
# ...

# %%
df['Category'] == 'BOOKS_AND_REFERENCE'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839     True
# 10840    False
# Name: Category, Length: 10841, dtype: bool

# %%
df_prod = df[df["Category"] == "ART_AND_DESIGN"]
len(df_prod[df_prod["Type"] == "Free"])
# Out:
# 62

# %%
df_prod = df[df["Category"] == "ART_AND_DESIGN"]
len(df_prod[df_prod["Rating"] >=4.1])
# Out:
# 52

# %%
df_prod = df[df["Category"] == "ART_AND_DESIGN"]
df_prod[df_prod["Rating"] >=4.1]
df_prod[df_prod["Type"] =='Paid']
# Out:
#                                                     App        Category  \
# 4755  X Launcher Pro: PhoneX Theme, OS11 Control Center  ART_AND_DESIGN
# 4759  X Launcher Pro - IOS Style Theme & Control Center  ART_AND_DESIGN
# 4764     X Launcher Prime: With OS Style Theme & No Ads  ART_AND_DESIGN
#
#       Rating Reviews  Size Installs  Type  Price Content Rating        Genres  \
# 4755     4.7     801  3.5M   5,000+  Paid  $1.99       Everyone  Art & Design
# 4759     4.8    1216  8.6M  10,000+  Paid  $1.99       Everyone  Art & Design
# 4764     4.7     149  3.5M   1,000+  Paid  $1.99       Everyone  Art & Design
#
#        Last Updated Current Ver Android Ver
# 4755  July 30, 2018       2.1.2  4.1 and up
# 4759  June 26, 2018       1.0.0  4.1 and up
# 4764  July 30, 2018       1.2.2  4.1 and up

# %%
df_prod = df[df["Category"] == "FAMILY"]
df_prod = df_prod[df_prod["Rating"] >=4.5]
df_prod[df_prod["Type"] =='Paid']["Price"]
# Out:
# 2151     $3.99
# 2154     $2.99
# 2168     $7.49
# 2170     $2.99
# 2172     $0.99
#          ...
# 9678     $1.99
# 9697     $2.99
# 9848     $4.99
# 10035    $0.99
# 10459    $1.99
# Name: Price, Length: 70, dtype: object

# %%
df_prod = df[df["Category"] == "FAMILY"]
df_prod = df_prod[df_prod["Rating"] >=4.5]
result = df_prod[df_prod["Type"] =='Paid'].values

# %%
for i in result:
   print(i[0],":",i[7])
# Out:
# Toca Life: City : $3.99
# Alizay, pirate girl : $2.99
# Children Educational Game Full : $7.49
# Hactar Go : $2.99
# World Racers family board game : $0.99
# Lanterns: The Harvest Festival : $4.99
# Tsuro - The Game of the Path : $2.99
# Chess and Mate : $4.99
# Avokiddo Emotions : $2.99
# Sago Mini Babies : $3.99
# Avokiddo Emotions : $2.99
# Sago Mini Babies : $3.99
# Minecraft : $6.99
# C4droid - C/C++ compiler & IDE : $2.99
# Mind Games Pro : $2.99
# Cut the Rope GOLD : $0.99
# K.MOJI : $1.99
# Math Games for Pre-K - Grade 4 : $1.99
# Fuzzy Numbers: Pre-K Number Foundation : $5.99
# Anna.K Tarot : $3.99
# Minecraft : $6.99
# Age of Conquest: N. America : $3.99
# Guns'n'Glory WW2 Premium : $2.99
# Q Avatar Pro : $1.49
# Day R Premium : $4.99
# FINAL FANTASY V : $7.99
# DRAGON QUEST V : $14.99
# X Construction : $1.49
# Z Origins - (Z The Game) : $2.99
# Math games for kids : times tables training : $1.59
# AG Subway Simulator Mobile : $0.99
# Age of AI: War Strategy : $2.49
# ...

# %%
df_pr = df['Category'] == 'FAMILY'
df_pr
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836     True
# 10837     True
# 10838    False
# 10839    False
# 10840    False
# Name: Category, Length: 10841, dtype: bool

# %%
df_pr = df[df['Category'] == 'FAMILY']
df_pr
# Out:
#                                     App Category  Rating  Reviews  \
# 2014                       YouTube Kids   FAMILY     4.5   470694
# 2015                         Candy Bomb   FAMILY     4.4    42145
# 2016                             ROBLOX   FAMILY     4.5  4449910
# 2017       Jewels Crush- Match 3 Puzzle   FAMILY     4.4    14774
# 2018                   Coloring & Learn   FAMILY     4.4    12753
# ...                                 ...      ...     ...      ...
# 10821                           Poop FR   FAMILY     NaN        6
# 10827                Fr Agnel Ambarnath   FAMILY     4.2      117
# 10834                     FR Calculator   FAMILY     4.0        7
# 10836                  Sya9a Maroc - FR   FAMILY     4.5       38
# 10837  Fr. Mike Schmitz Audio Teachings   FAMILY     5.0        4
#
#                      Size      Installs  Type Price Content Rating  \
# 2014   Varies with device   50,000,000+  Free     0       Everyone
# ...

# %%
df_pr = df_pr[df_pr["Rating"] >=4.5]
df_pr
# Out:
#                                                      App Category  Rating  \
# 2014                                        YouTube Kids   FAMILY     4.5
# 2016                                              ROBLOX   FAMILY     4.5
# 2019                                             Mahjong   FAMILY     4.5
# 2020   Super ABC! Learning games for kids! Preschool ...   FAMILY     4.6
# 2021                                       Toy Pop Cubes   FAMILY     4.5
# ...                                                  ...      ...     ...
# 10801                                Fr Ignacio Outreach   FAMILY     4.9
# 10809              Castle Clash: RPG War and Strategy FR   FAMILY     4.7
# 10820                                    Fr. Daoud Lamei   FAMILY     5.0
# 10836                                   Sya9a Maroc - FR   FAMILY     4.5
# 10837                   Fr. Mike Schmitz Audio Teachings   FAMILY     5.0
#
#        Reviews                Size      Installs  Type Price Content Rating  \
# ...
