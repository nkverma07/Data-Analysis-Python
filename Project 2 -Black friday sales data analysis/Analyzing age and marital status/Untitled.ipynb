# %%
import pandas as pd

# %%
df = pd.read_csv('BlackFriday.csv')

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.groupby('Age').size()
# Out:
# Age
# 0-17      14707
# 18-25     97634
# 26-35    214690
# 36-45    107499
# 46-50     44526
# 51-55     37618
# 55+       20903
# dtype: int64

# %%
df.groupby('Age').size().plot(kind='pie',autopct='%.1f')
# Out:
# <Axes: >

# %%
df.groupby('Age').size().plot(kind='pie',autopct='%.1f',figsize = (12,6),title = 'Purchase Distribution by Age')
# Out:
# <Axes: title={'center': 'Purchase Distribution by Age'}>

# %%
df[df['Age']=='0-17']
# Out:
#         User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0       1000001  P00069042      F  0-17          10             A
# 1       1000001  P00248942      F  0-17          10             A
# 2       1000001  P00087842      F  0-17          10             A
# 3       1000001  P00085442      F  0-17          10             A
# 85      1000019  P00112542      M  0-17          10             A
# ...         ...        ...    ...   ...         ...           ...
# 537280  1004690  P00242742      F  0-17          10             C
# 537281  1004690  P00226442      F  0-17          10             C
# 537282  1004690  P00181442      F  0-17          10             C
# 537283  1004690  P00192042      F  0-17          10             C
# 537354  1004707  P00253042      M  0-17           0             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
for i in df['Age'].unique():
    print(i,":",len(df[df['Age']==i]))
# Out:
# 0-17 : 14707
# 55+ : 20903
# 26-35 : 214690
# 46-50 : 44526
# 51-55 : 37618
# 36-45 : 107499
# 18-25 : 97634

# %%
df[df['Age']==i]['Product_ID'].nunique()
# Out:
# 3213

# %%
for i in df['Age'].unique():
    print(i,":",df[df['Age']==i]['Product_ID'].nunique())
# Out:
# 0-17 : 2300
# 55+ : 2573
# 26-35 : 3419
# 46-50 : 3099
# 51-55 : 2877
# 36-45 : 3318
# 18-25 : 3213

# %%
lst=[]
for i in df['Age'].unique():
    lst.append([i,df[df['Age']==i]['Product_ID'].nunique()])
lst
data = pd.DataFrame(lst,columns = ["Age","Products"])

# %%
data
# Out:
#      Age  Products
# 0   0-17      2300
# 1    55+      2573
# 2  26-35      3419
# 3  46-50      3099
# 4  51-55      2877
# 5  36-45      3318
# 6  18-25      3213

# %%
data.plot(kind='bar',x="Age",ylabel='Non Unique Products')
# Out:
# <Axes: xlabel='Age', ylabel='Non Unique Products'>

# %%
data.plot.bar(x='Age')
# Out:
# <Axes: xlabel='Age'>

# %%
df.groupby("Age").sum()['Purchase'].plot(kind='bar',figsize=(12,6),title="Amount Spend by Age")
# Out:
# <Axes: title={'center': 'Amount Spend by Age'}, xlabel='Age'>

# %%
df.groupby('Marital_Status').size().plot(kind = 'pie',autopct='%.1f')
# Out:
# <Axes: >

# %%
df.groupby('Marital_Status').size().plot(kind='pie',autopct='%.1f',title='Group By Marital Status')
# Out:
# <Axes: title={'center': 'Group By Marital Status'}>
